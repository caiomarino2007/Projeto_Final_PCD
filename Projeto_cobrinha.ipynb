# %%
#!pip install pygame
import pygame
import random
import sys
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\caio2610084\AppData\Roaming\Python\Python313\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
pygame.init()


#definindo a altura e largura da janela que executará o jogo
larg = 800
alt = 600

#criando a janela
janela = pygame.display.set_mode((larg, alt))
pygame.display.set_caption("Jogo da Cobrinha")


pygame.quit()
